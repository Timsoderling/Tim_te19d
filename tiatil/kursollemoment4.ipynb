# %%
#1


s1 = int(input("ange rektangelns första sida: "))
s2 = int(input("ange rektangelns andra sida: ")) 

if s1 == s2:
    print(f'Rektangeln har sidorna {s1} och {s2} detta gör att arean är {s1*s2}')
    print('sidorna är lika långa denna rektangeln är en kvadrat', "\n")

else:
    print(f'Rektangeln har sidorna {s1} och {s2} vilket gör att arean är {s1 * s2}', "\n")

print("Höjd | Volym") 
for h in range(1,11):    
    print(h," |",s1*s2*h )
# Out:
# Rektangeln har sidorna 5 och 5 detta gör att arean är 25
# sidorna är lika långa denna rektangeln är en kvadrat
#
# Höjd | Volym
# -------------
# 1  | 25
# 2  | 50
# 3  | 75
# 4  | 100
# 5  | 125
# 6  | 150
# 7  | 175
# 8  | 200
# 9  | 225
# 10  | 250

# %%
#2
from math import sqrt

y=int(input("ange ett heltal för sida a"))
x=int(input("ange ett heltal för sida b"))

a = y*x

if sqrt(a) == y and x:
    print(f"kvadratens area med sidorna {y**2} och {x**2} är: {a}")
else:
    print(f"rektangelns area med sidorna {y**2} och {x**2} är: {a}")
print("Höjd | Volym")
print("------------")
for c in range(1,11):
    print(c,"|",y*x*c)

svar = input("vill du forsätta beräkningen? svara ja eller nej!")
fortsätta = "ja"
stop = "nej"
if svar==fortsätta:
    y=int(input("ange ett heltal för sida a"))
    x=int(input("ange ett heltal för sida b"))
elif svar == stop:
    exit()


a = y*x

if sqrt(a) == y and x:
    print(f"kvadratens area med sidorna {y**2} och {x**2} är: {a}")
else:
    print(f"rektangelns area med sidorna {y**2} och {x**2} är: {a}")
print("Höjd | Volym")
print("------------")
for c in range(1,11):
    print(c,"|",y*x*c)
else:
    exit()

# %%
#3

sida1 = []
sida2 = []
area = []
hojd = []
volym = []
kvadrat = []

global counter
counter = 0

def areafunk(s1,s2):
    a = s1*s2
    return a

def volfunk(s1,s2,h):
    v = s1*s2*h
    return v

def kvadratfunk(s1,s2):
    if s1 == s2:
        return 'ja'

while True:
    userinput = input("Vill du göra en uträkning (Y/N): ").upper()

    if userinput == 'Y':
        counter += 1

        s1 = int(input("ange rektangelns första sida: "))
        sida1.append(s1)
        s2 = int(input("ange rektangelns andra sida: "))
        sida2.append(s2)

        while True:
            try:
                h = int(input("Ange rektangelns höjd: "))
                break
            except:
                print("inte ett heltal")

        if h < 0:
            h = 1
        elif h > 10:
            h = 10
        else:
            pass

        hojd.append(h)
        area.append(areafunk(s1,s2))
        volym.append(volfunk(s1,s2,h))
        kvadrat.append(kvadratfunk(s1,s2))

        if kvadratfunk(s1,s2) == 'ja':
            print(f"rektangelns area med sidorna {s1} & {s2} är {areafunk(s1,s2)}", "\n")
        else:
            print(f"Arean på rektangeln med sidorna {s1} & {s2} är {areafunk(s1,s2)}", "\n")

        print("Höjd | Volym")
        print("-------------")
        for h in range(1,h+1):
            print(h,"  |",s1*s2*h)

    else:
        for i in range(counter):
            if kvadrat[i] == 'ja':
                print(f"Beräkning {i+1} har sidorna {sida1[i]} och {sida2[i]} och arean blir {area[i]}, och det är en kvadrat")
            else:
                print(f"Beräkning {i+1} har sidorna {sida1[i]} och {sida2[i]} och arean blir {area[i]}")

        break

# %%
#4

from math import sqrt

counter = 0
s1 = []
s2 = []
arealist = []
höjd = []
volymlist = []
kvadratlist = []

def area(y,x):
    a = y*x
    return a

def volym(z,y,x):
    v = z*y*x
    return v

def kvadrat(x,y):
    if x == y: 
        return "ja"


while True:
    svar = input("Vill du fortsätta göra beräkningen? J / N?").upper()
    if svar == "":
        counter +=1

        y=int(input("ange ett heltal för sida a"))
        if y < 0:
            y = 1  
             s1.append(y)
   
        x=int(input("ange ett heltal för sida b"))
        if x < 0:
            x = 1  
        s2.append(x)
    
        z=int(input("ange en höjd för rektanglen"))
        if z < 0:
            z = 1  
        höjd.append(z)


        arealist.append(area(x,y))
        volymlist.append(volym(z,y,x))
        kvadratlist.append(kvadrat(x,y))

        if kvadrat(x,y) == "ja":
            print(f"arean på rektangel med sidorna {y} och {x} är {area(y,x)} och det är en kvadrat.")
        else:
            print(f"arean på rektangel med sidorna {y} och {x} är {area(y,x)}")
        

        print("Höjd | Volym")
        print("------------")
        for c in range(1,11):
            print(c,"|",y*x*c)
        
    else: 
        for i in range(counter):
            if kvadratlist[i] == "ja":
                print(f"Rektangeln har sidorna {s1[i]} och {s2[i]} vilket motsvarar att arean är {arealist[i]}, rektangeln är en kvadrat.")
            else:
                print(f"Rektangeln har sidorna {s1[i]} och {s2[i]} vilket motsvarar att arean är {arealist[i]}")            
        break
